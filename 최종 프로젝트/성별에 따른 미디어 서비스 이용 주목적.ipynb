# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rc('font' , family = 'NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
data = pd.read_excel('C:/Users/i5-8250U/Desktop/빅숙타/코로나19 이후 국민의 일상 변화 원본 데이터.xlsx')

# %%
data['SQ2'].value_counts()
# Out:
# 1    509
# 2    491
# Name: SQ2, dtype: int64

# %%
data['Q3_1'].value_counts()
# Out:
# 3    418
# 4    324
# 5    121
# 2     58
# 6     45
# 1     34
# Name: Q3_1, dtype: int64

# %%
data['Q3_2'].value_counts()
# Out:
# 4    359
# 3    330
# 5    185
# 6     59
# 2     45
# 1     22
# Name: Q3_2, dtype: int64

# %%
data['Q3_3'].value_counts()
# Out:
# 4    282
# 3    241
# 6    238
# 5    217
# 2     18
# 1      4
# Name: Q3_3, dtype: int64

# %%
data['Q3_4'].value_counts()
# Out:
# 4    301
# 3    296
# 5    233
# 6    145
# 2     17
# 1      8
# Name: Q3_4, dtype: int64

# %%
data['Q3_5'].value_counts()
# Out:
# 3    410
# 4    348
# 5    189
# 2     25
# 6     22
# 1      6
# Name: Q3_5, dtype: int64

# %%
data['Q3_6'].value_counts()
# Out:
# 3    414
# 4    236
# 6    183
# 5    121
# 2     28
# 1     18
# Name: Q3_6, dtype: int64

# %%
data['Q3_7'].value_counts()
# Out:
# 4    402
# 3    342
# 5    230
# 2     16
# 6      8
# 1      2
# Name: Q3_7, dtype: int64

# %%
data['Q22#1'].value_counts()
# Out:
#                      많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 지상파 채널                  34     58   418    324    121
# 종편, 보도채널, 기타 TV 채널      22     45   330    359    185
# 온라인 동영상 플랫폼(넷플릭스 등)     48     18   241    282    217
# 1인미디어 플랫폼(유튜브 등)         8     17   296    301    233
# 메신저 서비스                  6     25   410    348    189
# 소셜미디어                   18     28   414    236    121
# 포털(네이버, 구글 등)            2     16   342    402    230

# %%
fig, ax = plt.subplots(figsize=(30,20))
bar_width = 0.15

index = np.arange(7)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='red', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='blue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='green', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 7+ bar_width, 1), Media, fontsize=15)

plt.xlabel('Media', size = 20)
plt.ylabel('서비스 이용 변화량', size = 20)
plt.title('미디어 서비스 이용량', size=20)
plt.legend()
plt.show()

# %%
d1=data[['SQ2','Q3_1']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ2  Q3_1
# 1    1        16
#      2        32
#      3       235
#      4       151
#      5        49
#      6        26
# 2    1        18
#      2        26
#      3       183
#      4       173
#      5        72
#      6        19
# dtype: int64

# %%
dict_sex = {'많이 감소':[16,18], '조금 감소':[32,26],
                '변화없음':[235,183],'조금 증가':[151,173],
                '많이 증가':[49,72]}
Sex= ['남성', '여성']

df = pd.DataFrame(dict_sex, index = Sex)
df
# Out:
#     많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 남성     16     32   235    151     49
# 여성     18     26   183    173     72

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(2)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='red', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='blue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='green', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 2+ bar_width, 1), Sex, fontsize=10)

plt.xlabel('Sex', size = 10)
plt.ylabel('서비스 이용 변화량', size = 10)
plt.title('지상파 채널(KBS, MBC, SBS, EBS 등)')
plt.legend()
plt.show()

# %%
d1=data[['SQ2','Q3_2']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ2  Q3_2
# 1    1        13
#      2        31
#      3       180
#      4       172
#      5        79
#      6        34
# 2    1         9
#      2        14
#      3       150
#      4       187
#      5       106
#      6        25
# dtype: int64

# %%
dict_sex = {'많이 감소':[13,9], '조금 감소':[31,14],
                '변화없음':[180,150],'조금 증가':[172,187],
                '많이 증가':[79,106]}
Sex= ['남성','여성']

df = pd.DataFrame(dict_sex, index = Sex)
df
# Out:
#     많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 남성     13     31   180    172     79
# 여성      9     14   150    187    106

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(2)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='red', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='blue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='green', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 2+ bar_width, 1), Sex, fontsize=10)

plt.xlabel('Sex', size = 10)
plt.ylabel('서비스 이용 변화량', size = 10)
plt.title('종편, 보도채널, 기타 TV 채널(JTBC, YTN, tvN 등)')
plt.legend()
plt.show()

# %%
d1=data[['SQ2','Q3_3']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ2  Q3_3
# 1    1         1
#      2        12
#      3       141
#      4       148
#      5       101
#      6       106
# 2    1         3
#      2         6
#      3       100
#      4       134
#      5       116
#      6       132
# dtype: int64

# %%
dict_sex = {'많이 감소':[1,3], '조금 감소':[12,6],
                '변화없음':[141,100],'조금 증가':[148,134],
                '많이 증가':[101,116]}
Sex= ['남성','여성']

df = pd.DataFrame(dict_sex, index = Sex)
df
# Out:
#     많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 남성      1     12   141    148    101
# 여성      3      6   100    134    116

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(2)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='red', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='blue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='green', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 2+ bar_width, 1), Sex, fontsize=10)

plt.xlabel('Sex', size = 10)
plt.ylabel('서비스 이용 변화량', size = 10)
plt.title('온라인 동영상 플랫폼(넷플릭스, 웨이브, 티빙 등)')
plt.legend()
plt.show()

# %%
d1=data[['SQ2','Q3_4']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ2  Q3_4
# 1    1         3
#      2        10
#      3       172
#      4       156
#      5       118
#      6        50
# 2    1         5
#      2         7
#      3       124
#      4       145
#      5       115
#      6        95
# dtype: int64

# %%
dict_sex = {'많이 감소':[3,5], '조금 감소':[10,7],
                '변화없음':[172,124],'조금 증가':[156,145],
                '많이 증가':[118,115]}
Sex= ['남성','여성']

df = pd.DataFrame(dict_sex, index = Sex)
df
# Out:
#     많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 남성      3     10   172    156    118
# 여성      5      7   124    145    115

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(2)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='red', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='blue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='green', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 2+ bar_width, 1), Sex, fontsize=10)

plt.xlabel('Sex', size = 10)
plt.ylabel('서비스 이용 변화량', size = 10)
plt.title('1인미디어 플랫폼(유튜브, 아프리카TV, 트위치  등)')
plt.legend()
plt.show()

# %%
d1=data[['SQ2','Q3_5']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ2  Q3_5
# 1    1         1
#      2        11
#      3       235
#      4       168
#      5        83
#      6        11
# 2    1         5
#      2        14
#      3       175
#      4       180
#      5       106
#      6        11
# dtype: int64

# %%
dict_sex = {'많이 감소':[1,5], '조금 감소':[11,14],
                '변화없음':[235,175],'조금 증가':[168,180],
                '많이 증가':[83,106]}
Sex= ['남성','여성']

df = pd.DataFrame(dict_sex, index = Sex)
df
# Out:
#     많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 남성      1     11   235    168     83
# 여성      5     14   175    180    106

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(2)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='red', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='blue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='green', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 2+ bar_width, 1), Sex, fontsize=10)

plt.xlabel('Sex', size = 10)
plt.ylabel('서비스 이용 변화량', size = 10)
plt.title('메신저 서비스(카카오톡, 라인 등)')
plt.legend()
plt.show()

# %%
d1=data[['SQ2','Q3_6']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ2  Q3_6
# 1    1         9
#      2        13
#      3       244
#      4       123
#      5        56
#      6        64
# 2    1         9
#      2        15
#      3       170
#      4       113
#      5        65
#      6       119
# dtype: int64

# %%
dict_sex = {'많이 감소':[9,9], '조금 감소':[13,15],
                '변화없음':[244,170],'조금 증가':[123,113],
                '많이 증가':[56,65]}
Sex= ['남성','여성']

df = pd.DataFrame(dict_sex, index = Sex)
df
# Out:
#     많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 남성      9     13   244    123     56
# 여성      9     15   170    113     65

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(2)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='red', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='blue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='green', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 2+ bar_width, 1), Sex, fontsize=10)

plt.xlabel('Sex', size = 10)
plt.ylabel('서비스 이용 변화량', size = 10)
plt.title('소셜미디어(페이스북, 인스타그램 등)')
plt.legend()
plt.show()

# %%
d1=data[['SQ2','Q3_7']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ2  Q3_7
# 1    2         3
#      3       199
#      4       203
#      5       100
#      6         4
# 2    1         2
#      2        13
#      3       143
#      4       199
#      5       130
#      6         4
# dtype: int64

# %%
dict_sex = {'많이 감소':[0,2], '조금 감소':[3,13],
                '변화없음':[199,143],'조금 증가':[203,199],
                '많이 증가':[100,130]}
Sex= ['남성','여성']

df = pd.DataFrame(dict_sex, index = Sex)
df
# Out:
#     많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 남성      0      3   199    203    100
# 여성      2     13   143    199    130

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(2)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='red', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='blue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='green', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 2+ bar_width, 1), Sex, fontsize=10)

plt.xlabel('Sex', size = 10)
plt.ylabel('서비스 이용 변화량', size = 10)
plt.title('포털(네이버, 다음 구글 등)')
plt.legend()
plt.show()
