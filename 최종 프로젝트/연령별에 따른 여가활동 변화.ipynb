# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rc('font' , family = 'NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
data = pd.read_excel('C:/Users/i5-8250U/Desktop/빅숙타/코로나19 이후 국민의 일상 변화 원본 데이터.xlsx')

# %%
data['SQ3_R'].value_counts()
# Out:
# 5    235
# 4    221
# 2    193
# 3    186
# 6    165
# Name: SQ3_R, dtype: int64

# %%
data['Q1_18'].value_counts()
# Out:
# 3    282
# 1    235
# 4    160
# 2    144
# 5    104
# 9     75
# Name: Q1_18, dtype: int64

# %%
data['Q1_19'].value_counts()
# Out:
# 1    458
# 2    326
# 3    117
# 4     41
# 9     38
# 5     20
# Name: Q1_19, dtype: int64

# %%
data['Q1_23'].value_counts()
# Out:
# 4    373
# 5    322
# 3    247
# 2     31
# 1     16
# 9     11
# Name: Q1_23, dtype: int64

# %%
data['Q1_24'].value_counts()
# Out:
# 9    357
# 3    271
# 1    199
# 2    131
# 4     26
# 5     16
# Name: Q1_24, dtype: int64

# %%
data['Q1_25'].value_counts()
# Out:
# 3    319
# 2    277
# 4    158
# 1    156
# 5     51
# 9     39
# Name: Q1_25, dtype: int64

# %%
data['Q1_26'].value_counts()
# Out:
# 1    568
# 2    208
# 3    123
# 9     68
# 4     26
# 5      7
# Name: Q1_26, dtype: int64

# %%
data['Q1_28'].value_counts()
# Out:
# 4    373
# 5    250
# 3    238
# 2     84
# 1     41
# 9     14
# Name: Q1_28, dtype: int64

# %%
data['Q1_29'].value_counts()
# Out:
# 2    422
# 1    290
# 3    204
# 4     53
# 5     18
# 9     13
# Name: Q1_29, dtype: int64

# %%
data['Q1_30'].value_counts()
# Out:
# 1    597
# 2    197
# 3    107
# 9     67
# 4     19
# 5     13
# Name: Q1_30, dtype: int64

# %%
dict_avocation = {'많이 감소':[235,458,16,199,156,568,41,290,597], '조금 감소':[144,326,31,131,277,208,84,422,197],
                '변화없음':[282,117,247,271,319,123,238,204,107],'조금 증가':[160,41,373,26,158,26,373,53,19],
                '많이 증가':[104,20,322,16,51,7,250,18,13]}
Avocation= ['온라인 활동', '오프라인 활동', '미디어 이용', '종교생활' , '운동', '공연 등 현장관람', '온라인 쇼핑', '오프라인 쇼핑', '여행']

df = pd.DataFrame(dict_avocation, index = Avocation)
df
# Out:
#            많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 온라인 활동       235    144   282    160    104
# 오프라인 활동      458    326   117     41     20
# 미디어 이용        16     31   247    373    322
# 종교생활         199    131   271     26     16
# 운동           156    277   319    158     51
# 공연 등 현장관람    568    208   123     26      7
# 온라인 쇼핑        41     84   238    373    250
# 오프라인 쇼핑      290    422   204     53     18
# 여행           597    197   107     19     13

# %%
fig, ax = plt.subplots(figsize=(30,20))
bar_width = 0.15

index = np.arange(9)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 9+ bar_width, 1), Avocation, fontsize=15)

plt.xlabel('Avocation', size = 20)
plt.ylabel('변화량', size = 20)
plt.title('여가활동 변화량', size=20)
plt.legend()
plt.show()

# %%
d1=data[['SQ3_R','Q1_18']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ3_R  Q1_18
# 2      1        24
#        2        22
#        3        60
#        4        35
#        5        31
#        9        21
# 3      1        40
#        2        31
#        3        54
#        4        23
#        5        20
#        9        18
# 4      1        61
#        2        33
#        3        67
#        4        28
#        5        20
#        9        12
# 5      1        71
#        2        39
#        3        54
#        4        43
#        5        16
#        9        12
# 6      1        39
#        2        19
#        3        47
#        4        31
#        5        17
#        9        12
# dtype: int64

# %%
dict_age = {'많이 감소':[24,40,61,71,39], '조금 감소':[22,31,33,39,19],
                '변화없음':[60,54,67,54,47],'조금 증가':[35,23,28,43,31],
                '많이 증가':[31,20,20,16,17]}
Age= ['10~20대', '30대', '40대', '50대', '60대']

df = pd.DataFrame(dict_age, index = Age)
df
# Out:
#         많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 10~20대     24     22    60     35     31
# 30대        40     31    54     23     20
# 40대        61     33    67     28     20
# 50대        71     39    54     43     16
# 60대        39     19    47     31     17

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(5)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 5+ bar_width, 1), Age, fontsize=10)

plt.xlabel('Age', size = 10)
plt.ylabel('여가활동 변화량', size = 10)
plt.title('온라인 활동')
plt.legend()
plt.show()

# %%
d1=data[['SQ3_R','Q1_19']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ3_R  Q1_19
# 2      1         71
#        2         63
#        3         32
#        4          9
#        5          8
#        9         10
# 3      1         82
#        2         54
#        3         29
#        4          8
#        5          3
#        9         10
# 4      1        114
#        2         67
#        3         26
#        4          5
#        5          4
#        9          5
# 5      1        117
#        2         89
#        3         10
#        4         11
#        5          2
#        9          6
# 6      1         74
#        2         53
#        3         20
#        4          8
#        5          3
#        9          7
# dtype: int64

# %%
dict_age = {'많이 감소':[71,82,114,117,74], '조금 감소':[63,54,67,89,53],
                '변화없음':[32,29,26,10,20],'조금 증가':[9,8,5,11,8],
                '많이 증가':[8,3,4,2,3]}
Age= ['10~20대', '30대', '40대', '50대', '60대']

df = pd.DataFrame(dict_age, index = Age)
df
# Out:
#         많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 10~20대     71     63    32      9      8
# 30대        82     54    29      8      3
# 40대       114     67    26      5      4
# 50대       117     89    10     11      2
# 60대        74     53    20      8      3

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(5)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 5+ bar_width, 1), Age, fontsize=10)

plt.xlabel('Age', size = 10)
plt.ylabel('여가활동 변화량', size = 10)
plt.title('오프라인 활동')
plt.legend()
plt.show()

# %%
d1=data[['SQ3_R','Q1_23']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ3_R  Q1_23
# 2      1         2
#        2         7
#        3        39
#        4        61
#        5        81
#        9         3
# 3      1         4
#        2         8
#        3        54
#        4        59
#        5        59
#        9         2
# 4      1         4
#        2         4
#        3        56
#        4        89
#        5        68
# 5      1         2
#        2         6
#        3        48
#        4        96
#        5        79
#        9         4
# 6      1         4
#        2         6
#        3        50
#        4        68
#        5        35
#        9         2
# dtype: int64

# %%
dict_age = {'많이 감소':[2,4,4,2,4], '조금 감소':[7,8,4,6,6],
                '변화없음':[39,54,56,48,50],'조금 증가':[61,59,89,96,68],
                '많이 증가':[81,59,68,79,35]}
Age= ['10~20대', '30대', '40대', '50대', '60대']

df = pd.DataFrame(dict_age, index = Age)
df
# Out:
#         많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 10~20대      2      7    39     61     81
# 30대         4      8    54     59     59
# 40대         4      4    56     89     68
# 50대         2      6    48     96     79
# 60대         4      6    50     68     35

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(5)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 5+ bar_width, 1), Age, fontsize=10)

plt.xlabel('Age', size = 10)
plt.ylabel('여가활동 변화량', size = 10)
plt.title('미디어 이용')
plt.legend()
plt.show()

# %%
d1=data[['SQ3_R','Q1_24']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ3_R  Q1_24
# 2      1        25
#        2        15
#        3        53
#        4        10
#        5         4
#        9        86
# 3      1        44
#        2        13
#        3        56
#        4         3
#        5         4
#        9        66
# 4      1        45
#        2        22
#        3        65
#        4         7
#        5         3
#        9        79
# 5      1        51
#        2        50
#        3        50
#        4         4
#        5         3
#        9        77
# 6      1        34
#        2        31
#        3        47
#        4         2
#        5         2
#        9        49
# dtype: int64

# %%
dict_age = {'많이 감소':[25,44,45,51,34], '조금 감소':[15,13,22,50,31],
                '변화없음':[53,56,65,50,47],'조금 증가':[10,3,7,4,2],
                '많이 증가':[4,4,3,3,2]}
Age= ['10~20대', '30대', '40대', '50대', '60대']

df = pd.DataFrame(dict_age, index = Age)
df
# Out:
#         많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 10~20대     25     15    53     10      4
# 30대        44     13    56      3      4
# 40대        45     22    65      7      3
# 50대        51     50    50      4      3
# 60대        34     31    47      2      2

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(5)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 5+ bar_width, 1), Age, fontsize=10)

plt.xlabel('Age', size = 10)
plt.ylabel('여가활동 변화량', size = 10)
plt.title('종교생활')
plt.legend()
plt.show()

# %%
d1=data[['SQ3_R','Q1_25']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ3_R  Q1_25
# 2      1        21
#        2        46
#        3        52
#        4        43
#        5        19
#        9        12
# 3      1        29
#        2        50
#        3        57
#        4        28
#        5        10
#        9        12
# 4      1        36
#        2        62
#        3        86
#        4        26
#        5         8
#        9         3
# 5      1        39
#        2        76
#        3        70
#        4        33
#        5         8
#        9         9
# 6      1        31
#        2        43
#        3        54
#        4        28
#        5         6
#        9         3
# dtype: int64

# %%
dict_age = {'많이 감소':[21,29,36,39,31], '조금 감소':[46,50,62,76,43],
                '변화없음':[52,57,86,70,54],'조금 증가':[43,28,26,33,28],
                '많이 증가':[19,10,8,8,6]}
Age= ['10~20대', '30대', '40대', '50대', '60대']

df = pd.DataFrame(dict_age, index = Age)
df
# Out:
#         많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 10~20대     21     46    52     43     19
# 30대        29     50    57     28     10
# 40대        36     62    86     26      8
# 50대        39     76    70     33      8
# 60대        31     43    54     28      6

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(5)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 5+ bar_width, 1), Age, fontsize=10)

plt.xlabel('Age', size = 10)
plt.ylabel('여가활동 변화량', size = 10)
plt.title('운동')
plt.legend()
plt.show()

# %%
d1=data[['SQ3_R','Q1_26']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ3_R  Q1_26
# 2      1         93
#        2         34
#        3         34
#        4         11
#        5          5
#        9         16
# 3      1        100
#        2         40
#        3         28
#        4          6
#        5          1
#        9         11
# 4      1        139
#        2         45
#        3         27
#        4          2
#        5          1
#        9          7
# 5      1        143
#        2         53
#        3         18
#        4          3
#        9         18
# 6      1         93
#        2         36
#        3         16
#        4          4
#        9         16
# dtype: int64

# %%
dict_age = {'많이 감소':[93,100,139,143,93], '조금 감소':[34,40,45,53,36],
                '변화없음':[34,28,27,18,16],'조금 증가':[11,6,2,3,4],
                '많이 증가':[5,1,1,0,0]}
Age= ['10~20대', '30대', '40대', '50대', '60대']

df = pd.DataFrame(dict_age, index = Age)
df
# Out:
#         많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 10~20대     93     34    34     11      5
# 30대       100     40    28      6      1
# 40대       139     45    27      2      1
# 50대       143     53    18      3      0
# 60대        93     36    16      4      0

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(5)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 5+ bar_width, 1), Age, fontsize=10)

plt.xlabel('Age', size = 10)
plt.ylabel('여가활동 변화량', size = 10)
plt.title('공연 등 현장관람')
plt.legend()
plt.show()

# %%
d1=data[['SQ3_R','Q1_28']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ3_R  Q1_28
# 2      1         4
#        2        13
#        3        58
#        4        64
#        5        49
#        9         5
# 3      1         5
#        2        18
#        3        42
#        4        73
#        5        48
# 4      1         6
#        2        14
#        3        46
#        4        91
#        5        63
#        9         1
# 5      1        15
#        2        23
#        3        47
#        4        84
#        5        59
#        9         7
# 6      1        11
#        2        16
#        3        45
#        4        61
#        5        31
#        9         1
# dtype: int64

# %%
dict_age = {'많이 감소':[4,5,6,15,11], '조금 감소':[13,18,14,23,16],
                '변화없음':[58,42,46,47,45],'조금 증가':[49,73,91,84,61],
                '많이 증가':[49,48,63,59,31]}
Age= ['10~20대', '30대', '40대', '50대', '60대']

df = pd.DataFrame(dict_age, index = Age)
df
# Out:
#         많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 10~20대      4     13    58     49     49
# 30대         5     18    42     73     48
# 40대         6     14    46     91     63
# 50대        15     23    47     84     59
# 60대        11     16    45     61     31

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(5)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 5+ bar_width, 1), Age, fontsize=10)

plt.xlabel('Age', size = 10)
plt.ylabel('여가활동 변화량', size = 10)
plt.title('온라인 쇼핑')
plt.legend()
plt.show()

# %%
d1=data[['SQ3_R','Q1_29']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ3_R  Q1_29
# 2      1         53
#        2         73
#        3         44
#        4         12
#        5          3
#        9          8
# 3      1         58
#        2         73
#        3         39
#        4          7
#        5          7
#        9          2
# 4      1         63
#        2         99
#        3         45
#        4         10
#        5          4
# 5      1         82
#        2        101
#        3         34
#        4         12
#        5          3
#        9          3
# 6      1         34
#        2         76
#        3         42
#        4         12
#        5          1
# dtype: int64

# %%
dict_age = {'많이 감소':[53,58,63,82,34], '조금 감소':[73,73,99,101,76],
                '변화없음':[44,39,45,34,42],'조금 증가':[12,7,10,12,12],
                '많이 증가':[3,7,4,3,1]}
Age= ['10~20대', '30대', '40대', '50대', '60대']

df = pd.DataFrame(dict_age, index = Age)
df
# Out:
#         많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 10~20대     53     73    44     12      3
# 30대        58     73    39      7      7
# 40대        63     99    45     10      4
# 50대        82    101    34     12      3
# 60대        34     76    42     12      1

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(5)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 5+ bar_width, 1), Age, fontsize=10)

plt.xlabel('Age', size = 10)
plt.ylabel('여가활동 변화량', size = 10)
plt.title('오프라인 쇼핑')
plt.legend()
plt.show()

# %%
d1=data[['SQ3_R','Q1_30']]
d2=d1.value_counts().sort_index()
d2
# Out:
# SQ3_R  Q1_30
# 2      1         90
#        2         40
#        3         25
#        4          8
#        5          6
#        9         24
# 3      1        115
#        2         35
#        3         19
#        4          5
#        5          3
#        9          9
# 4      1        138
#        2         42
#        3         29
#        4          2
#        5          2
#        9          8
# 5      1        152
#        2         45
#        3         18
#        4          3
#        9         17
# 6      1        102
#        2         35
#        3         16
#        4          1
#        5          2
#        9          9
# dtype: int64

# %%
dict_age = {'많이 감소':[90,115,138,152,102], '조금 감소':[40,35,42,45,35],
                '변화없음':[25,19,29,18,16],'조금 증가':[8,5,2,3,1],
                '많이 증가':[6,3,2,0,2]}
Age= ['10~20대', '30대', '40대', '50대', '60대']

df = pd.DataFrame(dict_age, index = Age)
df
# Out:
#         많이 감소  조금 감소  변화없음  조금 증가  많이 증가
# 10~20대     90     40    25      8      6
# 30대       115     35    19      5      3
# 40대       138     42    29      2      2
# 50대       152     45    18      3      0
# 60대       102     35    16      1      2

# %%
fig, ax = plt.subplots(figsize=(15,10))
bar_width = 0.1

index = np.arange(5)

b1 = plt.bar(index, df['많이 감소'], bar_width, alpha=0.5, color='salmon', label='많이 감소')
b2 = plt.bar(index + bar_width, df['조금 감소'], bar_width, alpha=0.5, color='royalblue', label='조금 감소')
b3 = plt.bar(index + 2 * bar_width, df['변화없음'], bar_width, alpha=0.5, color='mediumpurple', label='변화없음')
b4 = plt.bar(index + 3 * bar_width, df['조금 증가'], bar_width, alpha=0.5, color='pink', label='조금 증가')
b5 = plt.bar(index + 4 * bar_width, df['많이 증가'], bar_width, alpha=0.5, color='yellow', label='많이 증가')

plt.xticks(np.arange(bar_width, 5+ bar_width, 1), Age, fontsize=10)

plt.xlabel('Age', size = 10)
plt.ylabel('여가활동 변화량', size = 10)
plt.title('여행')
plt.legend()
plt.show()
