# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rc('font' , family = 'NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
data  = pd.read_excel('C:/Users/i5-8250U/Desktop/빅숙타/코로나19 이후 국민의 일상 변화 원본 데이터.xlsx')

# %%
data['Q16_1'].value_counts()
# Out:
# 4    479
# 3    304
# 5    115
# 2     92
# 1     10
# Name: Q16_1, dtype: int64

# %%
x =['전혀 그렇지 않다','별로 그렇지 않다','보통이다','약간 그렇다','매우 그렇다']
y =[10,92,304,479,115]
plt.figure(figsize = (8,5))
bar = plt.bar(x, y, color='pink')
plt.title('정치나 사회 이슈 전반에 대한 관심이 늘었다')

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
   
plt.show()

# %%
data['Q16_2'].value_counts()
# Out:
# 4    384
# 3    345
# 2    134
# 5    115
# 1     22
# Name: Q16_2, dtype: int64

# %%
x =['전혀 그렇지 않다','별로 그렇지 않다','보통이다','약간 그렇다','매우 그렇다']
y =[22,134,345,384,115]
plt.figure(figsize = (8,5))
bar = plt.bar(x, y, color='pink')
plt.title('정치나 사회 이슈에 대한 정보를 적극적으로 찾아본다')

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
   
plt.show()

# %%
data['Q16_3'].value_counts()
# Out:
# 3    314
# 2    246
# 4    204
# 1    201
# 5     35
# Name: Q16_3, dtype: int64

# %%
x =['전혀 그렇지 않다','별로 그렇지 않다','보통이다','약간 그렇다','매우 그렇다']
y =[201,246,314,204,35]
plt.figure(figsize = (8,5))
bar = plt.bar(x, y, color='pink')
plt.title('정치나 사회 이슈 전반에 대해 온라인에서 게시물 또는 댓글을 작성하거나 오프라인에서 의견을 표현한다')

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
   
plt.show()

# %%
data['Q16_4'].value_counts()
# Out:
# 3    321
# 2    270
# 1    186
# 4    184
# 5     39
# Name: Q16_4, dtype: int64

# %%
x =['전혀 그렇지 않다','별로 그렇지 않다','보통이다','약간 그렇다','매우 그렇다']
y =[186,270,321,184,39]
plt.figure(figsize = (8,5))
bar = plt.bar(x, y, color='pink')
plt.title('정치나 사회 이슈와 관련해 온라인 또는 오프라인에서 정책 제안, 민원 제기, 서명, 정책 평가 등에 참여한다.')

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
   
plt.show()

# %%
data['Q16_5'].value_counts()
# Out:
# 3    316
# 2    254
# 1    239
# 4    149
# 5     42
# Name: Q16_5, dtype: int64

# %%
x =['전혀 그렇지 않다','별로 그렇지 않다','보통이다','약간 그렇다','매우 그렇다']
y =[239,254,316,149,42]
plt.figure(figsize = (8,5))
bar = plt.bar(x, y, color='pink')
plt.title('코로나19로 인해 지지하는 정치인이나 정당이 바뀌거나 새로 생겼다.')

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
   
plt.show()

# %%
data['Q16_6'].value_counts()
# Out:
# 1    298
# 3    276
# 2    256
# 4    136
# 5     34
# Name: Q16_6, dtype: int64

# %%
x =['전혀 그렇지 않다','별로 그렇지 않다','보통이다','약간 그렇다','매우 그렇다']
y =[298,256,276,136,34]
plt.figure(figsize = (8,5))
bar = plt.bar(x, y, color='pink')
plt.title('코로나19로 인해 나의 이념적 성향(진보, 보수)이 바뀌었다.')

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 12)
   
plt.show()
