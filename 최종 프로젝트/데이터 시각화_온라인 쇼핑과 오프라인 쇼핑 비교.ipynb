# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rc('font', family = 'NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
data = pd.read_excel('C:/Users/i5-8250U/Desktop/빅숙타/코로나19 이후 국민의 일상 변화 원본 데이터.xlsx')

# %%
data['Q1_28'].value_counts()
# Out:
# 4    373
# 5    250
# 3    238
# 2     84
# 1     41
# 9     14
# Name: Q1_28, dtype: int64

# %%
plt.figure(figsize = (5,5))
labels =['조금 증가','많이 증가','변화없음','조금 감소','많이 감소','해당없음']
plt.pie(data['Q1_28'].value_counts() , labels = labels , autopct = '%0.2f%%', colors=['orange','skyblue','lavender','pink','yellow','yellowgreen'])
plt.title('코로나19 확산 이후 온라인 쇼핑 이용량 변화')
plt.show()

# %%
data['Q1_29'].value_counts()
# Out:
# 2    422
# 1    290
# 3    204
# 4     53
# 5     18
# 9     13
# Name: Q1_29, dtype: int64

# %%
plt.figure(figsize = (5,5))
labels = ['조금 감소', '많이 감소', '변화없음', '조금 증가','많이 증가' , '해당없음']
plt.pie(data['Q1_29'].value_counts() , labels = labels , autopct = '%0.2f%%' , colors=['pink','yellow','lavender','orange','skyblue','yellowgreen'])
plt.title('코로나19 확산 이후 오프라인 쇼핑 이용량 변화')
plt.show()
